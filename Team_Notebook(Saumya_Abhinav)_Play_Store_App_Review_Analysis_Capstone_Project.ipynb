# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyadash9/Play-Store-App-Review-Analysis-Capstone-Project/blob/main/Team_Notebook(Saumya_Abhinav)_Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# # **Importing Required Libraries**

# %%
#importing pandas for data manipulation
import pandas as pd   
# importing numpy for mathematical operation
import numpy as np                
#importing matplotlib and seaborn for data visualization
import matplotlib.pyplot as plt     
import seaborn as sns
 # importing module for ignoring warnings 
import warnings                  
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Mounting Drive and Loading data for analysis**

# %%
# mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# importing primary data set on Play store app review Analysis
df = pd.read_csv("/content/drive/MyDrive/Copy of Play Store Data.csv")

# %%
# importing secondry data set on user review analysis
df1 = pd.read_csv("/content/drive/MyDrive/Copy of User Reviews.csv")

# %% [markdown]
# # **Basic Data Overview**

# %% [markdown]
# **For Primary DataFrame :**

# %%
# printing top 5 instances
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#printing bottom 5 instances
df.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
#printing the shape of the dataframe
df.shape
# Out:
# (10841, 13)

# %%
#checking for column wise information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
 #checking for duplicated instance in the primary dataframe
len(df[df.duplicated()])
# Out:
# 483

# %%
 # here we can see that only one column "Rating" is numeric and other numeric attributes are in string.
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#checking for null values column wise
df.isnull().sum().sort_values(ascending=False)
# Out:
# Rating            1474
# Current Ver          8
# Android Ver          3
# Type                 1
# Content Rating       1
# App                  0
# Category             0
# Reviews              0
# Size                 0
# Installs             0
# Price                0
# Genres               0
# Last Updated         0
# dtype: int64

# %% [markdown]
# **for secondary dataframe:**

# %%
 #printing first 5 instances of secondary dataset
 df1.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
 #printing last 5 instances of secondary dataset
df1.tail(5)
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
#checking the shape of secondary dataset
df1.shape
# Out:
# (64295, 5)

# %%
#checking column wise information 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
#checking for duplicated instance in secondary dataframe
len(df1[df1.duplicated()])
# Out:
# 33616

# %%
#checking for description of numerical datatypes
df1.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
#checking for all the null values
df1.isnull().sum().sort_values(ascending=False)
# Out:
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# App                           0
# dtype: int64

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# **Task at hand :**
#
# 1.   Drop duplicated instances from both the data frames.
# 2.   Drop or substitute null values as per requirement.
# 3.   Replace Numerical columns given as 'object' to float values.
# 4.   Conversion of different units given for a particular column to a common one to avoid miscalculation.
# 5. Drop or replace wrong data as per requirement.

# %% [markdown]
# **Dropping the duplicated instances**

# %%
#dropping the duplicates from primary dataframe 
df = df.drop_duplicates()

# %%
#dropping the duplicates from secondary dataframe
df1 = df1.drop_duplicates()

# %% [markdown]
# **Lets treat the 'Rating' column**

# %%
# we know that column 'rating'  is in integer form so lets chek for null values
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %% [markdown]
# Since some of the apps are not rated so we need to replace null values and wrong ratings with zero.

# %%
#1. Substituting the Null and values greater than 5 (wrong ratings) with 0
df['Rating'] = df['Rating'].fillna(0)
df['Rating'] = df['Rating'].replace(19.,0,regex = True)

# %%
# yeahhh Rating column is treated
df['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 0. , 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8,
#        2.7, 1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %%
df.Reviews.unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %% [markdown]
# **Lets Tackle the Reviews column now**

# %%
# converting the string data to numeric
df['Reviews'] = pd.to_numeric(df['Reviews'],errors ='coerce')
# substituting all the null values in data set with 0
df['Reviews'] = df['Reviews'].replace(np.nan,0,regex = True)
# changing the data type of Reviews to integers
df['Reviews'] = df['Reviews'].astype(int)

# %% [markdown]
# **Lets Treat the price column**

# %%
df['Price'].unique() #we have to remove the dollor symbols and then convert it into float
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %% [markdown]
# In the above cell we can see that there is a wrong values "Everyone" out of no where, lets eliminate it

# %%
# checking for Everyone(wrong data)
temp_df = df['Price'].value_counts().reset_index()
temp_df[temp_df["index"]=="Everyone"]
# Out:
#        index  Price
# 52  Everyone      1

# %%
# Eliminating dollar symbol
df['Price'] = df['Price'].str.replace('$','')
# Replacing Everyone with 0
df['Price'] = df['Price'].replace('Everyone',0,regex = True)
# Now converting the data type into float
df['Price'] = df['Price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          10358 non-null  float64
#  3   Reviews         10358 non-null  int64
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %% [markdown]
# **Lets treat Installs column**

# %%
#checking for unique values in the column
df.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %% [markdown]
# In the Installs column:
# 1. '+' (plus) symbol which we need to remove
# 2. to convert the string to float,
# 3. there is a wrong data "Free" which we need to eliminate or replace.

# %%
# replacing the plus symbol with nothing 
df.Installs = df.Installs.apply(lambda x:x.replace('+',''))
# replacing wrong data "Free" with "0" 
df['Installs'] = df['Installs'].replace('Free',"0",regex = True)
# replacing comma(,) with empty string
df['Installs'] = df['Installs'].replace(',','',regex = True)
# finally we will convert the data into float
df['Installs'] = df['Installs'].astype(float)

# %% [markdown]
# **Let us treat the Size column now**

# %%
df.Size.unique()    # checking for unique values in the column
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %% [markdown]
# To convert the string data in Size Column into numerical data we need to do the following task:
#
# * Remove M and K from the data
# * convert it into common unit (kb) in float  (considering 1 mb = 1000 kb)

# %%
def Replace_M_k(x):
  ''' this function takes the row element (Size column) and 
      returns te replacement of 'M' with 000 and 'k' with nothing
      and 0 if there is other data than above.
  '''
  if "M" in x:
    return x.replace("M","000")
  elif "k" in x :
    return x.replace("k","")
  else:
    return 0

# %%
# applying the above function for each row
df['Size'] = df['Size'].apply(Replace_M_k)

# %%
 # converting the data type to float
df['Size'] = df['Size'].astype(float)

# %%
#we can see that some values(less than 20 mb) remained unaltered by above operation so we need to multiply it with 1000.
print(list(df.Size.unique()) )
# Out:
# [19000.0, 14000.0, 8.7, 25000.0, 2.8, 5.6, 29000.0, 33000.0, 3.1, 28000.0, 12000.0, 20000.0, 21000.0, 37000.0, 2.7, 5.5, 17000.0, 39000.0, 31000.0, 4.2, 7.0, 23000.0, 6.0, 6.1, 4.6, 9.2, 5.2, 11000.0, 24000.0, 0.0, 9.4, 15000.0, 10000.0, 1.2, 26000.0, 8.0, 7.9, 56000.0, 57000.0, 35000.0, 54000.0, 201.0, 3.6, 5.7, 8.6, 2.4, 27000.0, 2.5, 16000.0, 3.4, 8.9, 3.9, 2.9, 38000.0, 32000.0, 5.4, 18000.0, 1.1, 2.2, 4.5, 9.8, 52000.0, 9.0, 6.7, 30000.0, 2.6, 7.1, 3.7, 22000.0, 7.4, 6.4, 3.2, 8.2, 9.9, 4.9, 9.5, 5.0, 5.9, 13000.0, 73000.0, 6.8, 3.5, 4.0, 2.3, 7.2, 2.1, 42000.0, 7.3, 9.1, 55000.0, 23.0, 6.5, 1.5, 7.5, 51000.0, 41000.0, 48000.0, 8.5, 46000.0, 8.3, 4.3, 4.7, 3.3, 40000.0, 7.8, 8.8, 6.6, 5.1, 61000.0, 66000.0, 79.0, 8.4, 118.0, 44000.0, 695.0, 1.6, 6.2, 18.0, 53000.0, 1.4, 3.0, 5.8, 3.8, 9.6, 45000.0, 63000.0, 49000.0, 77000.0, 4.4, 4.8, 70000.0, 6.9, 9.3, 10.0, 8.1, 36000.0, 84000.0, 97000.0, 2.0, 1.9, 1.8, 5.3, 47000.0, 556.0, 526.0, 76000.0, 7.6, 59000.0, 9.7, 78000.0, 72000.0, 43000.0, 7.7, 6.3, 334.0, 34000.0, 93000.0, 65000.0, 79000.0, 100000.0, 58000.0, 50000.0, 68000.0, 64000.0, 67000.0, 60000.0, 94000.0, 232.0, 99000.0, 624.0, 95000.0, 41.0, 292.0, 11.0, 80000.0, 1.7, 74000.0, 62000.0, 69000.0, 75000.0, 98000.0, 85000.0, 82000.0, 96000.0, 87000.0, 71000.0, 86000.0, 91000.0, 81000.0, 92000.0, 83000.0, 88000.0, 704.0, 862.0, 899.0, 378.0, 266.0, 375.0, 1.3, 975.0, 980.0, 4.1, 89000.0, 696.0, 544.0, 525.0, 920.0, 779.0, 853.0, 720.0, 713.0, 772.0, 318.0, 58.0, 241.0, 196.0, 857.0, 51.0, 953.0, 865.0, 251.0, 930.0, 540.0, 313.0, 746.0, 203.0, 26.0, 314.0, 239.0, 371.0, 220.0, 730.0, 756.0, 91.0, 293.0, 17.0, 74.0, 14.0, 317.0, 78.0, 924.0, 902.0, 818.0, 81.0, 939.0, 169.0, 45.0, 475.0, 965.0, 90000.0, 545.0, 61.0, 283.0, 655.0, 714.0, 93.0, 872.0, 121.0, 322.0, 1.0, 976.0, 172.0, 238.0, 549.0, 206.0, 954.0, 444.0, 717.0, 210.0, 609.0, 308.0, 705.0, 306.0, 904.0, 473.0, 175.0, 350.0, 383.0, 454.0, 421.0, 70.0, 812.0, 442.0, 842.0, 417.0, 412.0, 459.0, 478.0, 335.0, 782.0, 721.0, 430.0, 429.0, 192.0, 200.0, 460.0, 728.0, 496.0, 816.0, 414.0, 506.0, 887.0, 613.0, 243.0, 569.0, 778.0, 683.0, 592.0, 319.0, 186.0, 840.0, 647.0, 191.0, 373.0, 437.0, 598.0, 716.0, 585.0, 982.0, 222.0, 219.0, 55.0, 948.0, 323.0, 691.0, 511.0, 951.0, 963.0, 25.0, 554.0, 351.0, 27.0, 82.0, 208.0, 913.0, 514.0, 551.0, 29.0, 103.0, 898.0, 743.0, 116.0, 153.0, 209.0, 353.0, 499.0, 173.0, 597.0, 809.0, 122.0, 411.0, 400.0, 801.0, 787.0, 237.0, 50.0, 643.0, 986.0, 97.0, 516.0, 837.0, 780.0, 961.0, 269.0, 20.0, 498.0, 600.0, 749.0, 642.0, 881.0, 72.0, 656.0, 601.0, 221.0, 228.0, 108.0, 940.0, 176.0, 33.0, 663.0, 34.0, 942.0, 259.0, 164.0, 458.0, 245.0, 629.0, 28.0, 288.0, 775.0, 785.0, 636.0, 916.0, 994.0, 309.0, 485.0, 914.0, 903.0, 608.0, 500.0, 54.0, 562.0, 847.0, 957.0, 688.0, 811.0, 270.0, 48.0, 329.0, 523.0, 921.0, 874.0, 981.0, 784.0, 280.0, 24.0, 518.0, 754.0, 892.0, 154.0, 860.0, 364.0, 387.0, 626.0, 161.0, 879.0, 39.0, 970.0, 170.0, 141.0, 160.0, 144.0, 143.0, 190.0, 376.0, 193.0, 246.0, 73.0, 658.0, 992.0, 253.0, 420.0, 404.0, 470.0, 226.0, 240.0, 89.0, 234.0, 257.0, 861.0, 467.0, 157.0, 44.0, 676.0, 67.0, 552.0, 885.0, 1020.0, 582.0, 619.0]

# %%
# multiplying the unaltered values with 1000 and passing the whole column element into list
size_list = []
for i in df.Size:
  if i< 20.0:
    size_list.append(i*1000)
  else:
    size_list.append(i)

# %%
#replacing the whole column with new set of treated values
df["Size"] = pd.DataFrame(size_list)

# %%
print(list(df['Size'].unique()))
# Out:
# [19000.0, 14000.0, 8700.0, 25000.0, 2800.0, 5600.0, 29000.0, 33000.0, 3100.0, 28000.0, 12000.0, 20000.0, 21000.0, 37000.0, 2700.0, 5500.0, 17000.0, 39000.0, 31000.0, 4200.0, 7000.0, 23000.0, 6000.0, 6100.0, 4600.0, 9200.0, 5200.0, 11000.0, 24000.0, 0.0, 9400.0, 15000.0, 10000.0, 1200.0, 26000.0, 8000.0, 7900.0, 56000.0, 57000.0, 35000.0, 54000.0, 201.0, 3600.0, 5700.0, 8600.0, 2400.0, 27000.0, 2500.0, 16000.0, 3400.0, 8900.0, 3900.0, 2900.0, 38000.0, 32000.0, 5400.0, 18000.0, 1100.0, 2200.0, 4500.0, 9800.0, 52000.0, 9000.0, 6700.0, 30000.0, 2600.0, 7100.0, 3700.0, 22000.0, 7400.0, 6400.0, 3200.0, 8200.0, 9900.0, 4900.0, 9500.0, 5000.0, 5900.0, 13000.0, 73000.0, 6800.0, 3500.0, 4000.0, 2300.0, 7200.0, 2100.0, 42000.0, 7300.0, 9100.0, 55000.0, 23.0, 6500.0, 1500.0, 7500.0, 41000.0, 48000.0, 8500.0, 46000.0, 7800.0, 8800.0, 6600.0, 5100.0, 3300.0, 40000.0, 61000.0, 66000.0, 79.0, 8300.0, 8400.0, 4300.0, 4700.0, 118.0, 44000.0, 695.0, 1600.0, 53000.0, 6200.0, 1400.0, 5800.0, 3800.0, 9600.0, 45000.0, 63000.0, 49000.0, 77000.0, 4400.0, 9300.0, 8100.0, 36000.0, 51000.0, 3000.0, 6900.0, 84000.0, 97000.0, 5300.0, 47000.0, 76000.0, 1800.0, 7600.0, 59000.0, 9700.0, 78000.0, 72000.0, 7700.0, 6300.0, 334.0, 70000.0, 93000.0, 65000.0, 79000.0, 100000.0, 50000.0, 68000.0, 64000.0, 43000.0, 34000.0, 58000.0, 67000.0, 60000.0, 94000.0, 1900.0, 232.0, 99000.0, 95000.0, 41.0, 292.0, 80000.0, 1700.0, 74000.0, 62000.0, 69000.0, 75000.0, 98000.0, 85000.0, 82000.0, 96000.0, 87000.0, 71000.0, 86000.0, 91000.0, 81000.0, 92000.0, 83000.0, 88000.0, 704.0, 862.0, 899.0, 378.0, 4800.0, 266.0, 375.0, 1300.0, 2000.0, 975.0, 4100.0, 89000.0, 696.0, 544.0, 525.0, 920.0, 779.0, 853.0, 720.0, 713.0, 772.0, 318.0, 58.0, 241.0, 196.0, 857.0, 51.0, 865.0, 251.0, 930.0, 540.0, 313.0, 746.0, 203.0, 26.0, 314.0, 239.0, 371.0, 220.0, 730.0, 756.0, 91.0, 293.0, 74.0, 317.0, 78.0, 924.0, 902.0, 818.0, 81.0, 939.0, 169.0, 45.0, 475.0, 965.0, 90000.0, 545.0, 61.0, 283.0, 655.0, 714.0, 93.0, 872.0, 121.0, 322.0, 1000.0, 976.0, 172.0, 238.0, 549.0, 206.0, 954.0, 444.0, 717.0, 210.0, 609.0, 308.0, 705.0, 306.0, 904.0, 473.0, 175.0, 350.0, 383.0, 454.0, 421.0, 70.0, 812.0, 442.0, 842.0, 417.0, 412.0, 459.0, 478.0, 335.0, 782.0, 721.0, 430.0, 429.0, 192.0, 200.0, 460.0, 728.0, 496.0, 816.0, 414.0, 506.0, 887.0, 613.0, 243.0, 569.0, 778.0, 683.0, 592.0, 319.0, 186.0, 840.0, 647.0, 191.0, 373.0, 437.0, 598.0, 716.0, 585.0, 982.0, 222.0, 219.0, 55.0, 948.0, 323.0, 691.0, 511.0, 951.0, 963.0, 25.0, 554.0, 351.0, 27.0, 82.0, 208.0, 913.0, 514.0, 551.0, 29.0, 103.0, 898.0, 743.0, 116.0, 153.0, 209.0, 353.0, 499.0, 173.0, 597.0, 809.0, 122.0, 411.0, 400.0, 801.0, 787.0, 237.0, 50.0, 643.0, 986.0, 97.0, 516.0, 837.0, 780.0, 961.0, 269.0, 20.0, 498.0, 600.0, 749.0, 642.0, 881.0, 72.0, 656.0, 601.0, 221.0, 228.0, 108.0, 940.0, 176.0, 33.0, 663.0, 34.0, 942.0, 259.0, 164.0, 458.0, 245.0, 629.0, 28.0, 288.0, 775.0, 785.0, 636.0, 916.0, 994.0, 309.0, 485.0, 914.0, 903.0, 608.0, 500.0, 54.0, 562.0, 957.0, 688.0, 811.0, 270.0, 48.0, 329.0, 523.0, 921.0, 874.0, 981.0, 784.0, 280.0, 24.0, 518.0, 754.0, 892.0, 154.0, 860.0, 364.0, 387.0, 626.0, 161.0, 879.0, 39.0, 970.0, 170.0, 141.0, 160.0, 144.0, 143.0, 190.0, 376.0, 193.0, 246.0, 73.0, 658.0, 992.0, 253.0, 420.0, 404.0, 470.0, 226.0, 240.0, 89.0, 234.0, 257.0, 861.0, 467.0, 157.0, 44.0, 676.0, 67.0, 552.0, 885.0, 1020.0, 582.0, 619.0, nan]

# %%
df.isnull().sum().sort_values(ascending=False)  #lets check once how many null values are still left across the columns
# Out:
# Size              482
# Current Ver         8
# Android Ver         3
# Type                1
# Content Rating      1
# App                 0
# Category            0
# Rating              0
# Reviews             0
# Installs            0
# Price               0
# Genres              0
# Last Updated        0
# dtype: int64

# %% [markdown]
# **Treating "Content Rating" column**

# %%
df[df['Content Rating'].isnull()] #checking for the index of null values
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9     0.0        0
#
#        Size  Installs Type  Price Content Rating             Genres  \
# 10472   NaN       0.0    0    0.0            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df= df.drop(10472) #dropping the column with null values

# %% [markdown]
# ### **Treating "type" column**

# %%
# We will do the task same as above in this column as well
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
df[df['Type'].isnull()]
# Out:
#                             App Category  Rating  Reviews     Size  Installs  \
# 9148  Command & Conquer: Rivals   FAMILY     0.0        0  53000.0       0.0
#
#      Type  Price Content Rating    Genres   Last Updated         Current Ver  \
# 9148  NaN    0.0   Everyone 10+  Strategy  June 28, 2018  Varies with device
#
#              Android Ver
# 9148  Varies with device

# %%
df= df.drop(9148)

# %% [markdown]
# **Treating column "Android ver" column**

# %%
df[df['Android Ver'].isnull()] #checking for null values
# Out:
#                          App         Category  Rating  Reviews    Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4      230  5100.0
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5      189     0.0
#
#       Installs  Type  Price Content Rating           Genres    Last Updated  \
# 4453    1000.0  Paid   1.49       Everyone  Personalization   July 20, 2018
# 4490   10000.0  Free   0.00       Everyone  Personalization  March 27, 2018
#
#      Current Ver Android Ver
# 4453         4.4         NaN
# 4490         1.1         NaN

# %%
#finding the most frequent data in the column
temp_df = df.groupby('Android Ver').App.count().sort_values(ascending = False).reset_index() 
temp_df
# Out:
#            Android Ver   App
# 0           4.1 and up  2379
# 1         4.0.3 and up  1451
# 2           4.0 and up  1337
# 3   Varies with device  1220
# 4           4.4 and up   894
# 5           2.3 and up   643
# 6           5.0 and up   546
# 7           4.2 and up   387
# 8         2.3.3 and up   279
# 9           2.2 and up   239
# 10          3.0 and up   237
# 11          4.3 and up   235
# 12          2.1 and up   133
# 13          1.6 and up   116
# 14          6.0 and up    58
# 15          7.0 and up    42
# 16          3.2 and up    36
# 17          2.0 and up    32
# 18          5.1 and up    22
# 19          1.5 and up    20
# 20         4.4W and up    11
# 21          3.1 and up    10
# 22        2.0.1 and up     7
# 23          8.0 and up     6
# 24          7.1 and up     3
# 25          1.0 and up     2
# 26           5.0 - 8.0     2
# 27       4.0.3 - 7.1.1     2
# 28         5.0 - 7.1.1     1
# 29         7.0 - 7.1.1     1
# 30           5.0 - 6.0     1
# 31         2.2 - 7.1.1     1
# 32         4.1 - 7.1.1     1

# %%
# Replacing the null values with most frequent android version
df['Android Ver'] = df['Android Ver'].replace(np.nan,"4.1 and up")

# %% [markdown]
# **Treating 'current ver' column**

# %% [markdown]
# we will do the same task for this column as above

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2       55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1    20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2     4010
# 6803                         BT Master               FAMILY     0.0        0
# 7333                       Dots puzzle               FAMILY     4.0      179
# 7407                   Calculate My IQ               FAMILY     0.0       44
# 7730                            UFO-CQ                TOOLS     0.0        1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     0.0        8
#
#           Size   Installs  Type  Price Content Rating             Genres  \
# 15      2700.0     5000.0  Free   0.00       Everyone       Art & Design
# 1553   32000.0  1000000.0  Free   0.00       Everyone   Libraries & Demo
# 6322     585.0   500000.0  Free   0.00       Everyone              Tools
# 6803    8800.0      100.0  Free   0.00       Everyone          Education
# 7333   18000.0    50000.0  Paid   0.99       Everyone             Puzzle
# 7407    9600.0    10000.0  Free   0.00       Everyone      Entertainment
# 7730    1500.0       10.0  Paid   0.99       Everyone              Tools
# 10342   7700.0     1000.0  Free   0.00       Everyone  Books & Reference
#
#             Last Updated Current Ver Android Ver
# 15          June 6, 2018         NaN  4.2 and up
# 1553   February 12, 2013         NaN  1.5 and up
# 6322        May 10, 2017         NaN  4.0 and up
# 6803    November 6, 2016         NaN  1.6 and up
# 7333      April 18, 2018         NaN  4.0 and up
# 7407       April 3, 2017         NaN  2.3 and up
# 7730        July 4, 2016         NaN  2.0 and up
# 10342   January 31, 2017         NaN  3.0 and up

# %%
temp_df1 = df.groupby('Current Ver').App.count().sort_values(ascending = False).reset_index()
temp_df1
# Out:
#              Current Ver   App
# 0     Varies with device  1301
# 1                    1.0   802
# 2                    1.1   260
# 3                    1.2   177
# 4                    2.0   149
# ...                  ...   ...
# 2826            2.1.6579     1
# 2827              2.1.56     1
# 2828              2.1.54     1
# 2829              2.1.35     1
# 2830       version 0.994     1
#
# [2831 rows x 2 columns]

# %%
df['Current Ver'] = df['Current Ver'].replace(np.nan,"Varies with device")

# %%
df.isnull().sum().sort_values(ascending=False)  # finally there is no null values
# Out:
# Size              481
# App                 0
# Category            0
# Rating              0
# Reviews             0
# Installs            0
# Type                0
# Price               0
# Content Rating      0
# Genres              0
# Last Updated        0
# Current Ver         0
# Android Ver         0
# dtype: int64

# %%
df.describe()
# Out:
#              Rating       Reviews           Size      Installs         Price
# count  10356.000000  1.035600e+04    9875.000000  1.035600e+04  10356.000000
# mean       3.595848  4.059438e+05   18163.318380  1.415913e+07      1.030900
# std        1.537319  2.696905e+06   22157.272563  8.024331e+07     16.279408
# min        0.000000  0.000000e+00       0.000000  0.000000e+00      0.000000
# 25%        3.700000  3.200000e+01    2700.000000  1.000000e+03      0.000000
# 50%        4.200000  1.683000e+03    9100.000000  1.000000e+05      0.000000
# 75%        4.500000  4.643825e+04   26000.000000  1.000000e+06      0.000000
# max        5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000

# %% [markdown]
# **Data Cleaning in 2nd Data Frame**

# %%
 # checking for the null values
df1.isnull().sum().sort_values(ascending=False)
# Out:
# Translated_Review         987
# Sentiment                 982
# Sentiment_Polarity        982
# Sentiment_Subjectivity    982
# App                         0
# dtype: int64

# %%
# dropping all the null vaues from entire data frame
df1 = df1.dropna()

# %%
df1.isnull().sum().sort_values(ascending=False)
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29692 entries, 0 to 64230
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     29692 non-null  object
#  1   Translated_Review       29692 non-null  object
#  2   Sentiment               29692 non-null  object
#  3   Sentiment_Polarity      29692 non-null  float64
#  4   Sentiment_Subjectivity  29692 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # **Data Analysis and Visualization**

# %% [markdown]
# **Lets check the distribution of the numerical columns in primary data set using histograms.**

# %%
df.hist(color = 'brown')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6ddec73f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6de1b57b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6de1b10190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6ddebaea90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6ddeb7dd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6ddeb413d0>]],
#       dtype=object)

# %%
df1.hist(color = 'steelblue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6dde99e190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6dde9536d0>]],
#       dtype=object)

# %% [markdown]
# ## **Problem Statement 1 - Which Category has the maximum and minimum number of apps?**

# %%
# doing groupby operation to extract no. of apps in each catgory
df_category_vs_count = df.groupby('Category').App.count().sort_values(ascending = False).reset_index()
# renaming the columns  
df_category_vs_count.rename(columns = {'Category':'App Catagory', 'App':'No. of Apps'}, inplace = True)

# %%
 #We can see the output of above groupby operation
 df_category_vs_count
# Out:
#            App Catagory  No. of Apps
# 0                FAMILY         1942
# 1                  GAME         1121
# 2                 TOOLS          843
# 3              BUSINESS          427
# 4               MEDICAL          408
# 5          PRODUCTIVITY          407
# 6       PERSONALIZATION          388
# 7             LIFESTYLE          373
# 8         COMMUNICATION          366
# 9               FINANCE          360
# 10               SPORTS          351
# 11          PHOTOGRAPHY          322
# 12   HEALTH_AND_FITNESS          306
# 13               SOCIAL          280
# 14   NEWS_AND_MAGAZINES          264
# 15     TRAVEL_AND_LOCAL          237
# 16  BOOKS_AND_REFERENCE          230
# 17             SHOPPING          224
# 18               DATING          196
# 19        VIDEO_PLAYERS          175
# 20  MAPS_AND_NAVIGATION          137
# 21            EDUCATION          130
# 22       FOOD_AND_DRINK          124
# 23        ENTERTAINMENT          111
# 24   LIBRARIES_AND_DEMO           85
# 25    AUTO_AND_VEHICLES           85
# 26              WEATHER           82
# 27       HOUSE_AND_HOME           80
# 28       ART_AND_DESIGN           65
# 29               EVENTS           64
# 30            PARENTING           60
# 31               COMICS           60
# 32               BEAUTY           53

# %%
# Plotting the bar graph to see the popularity of each category in terms of number of apps
plt.figure(figsize=(15, 8))
sns.barplot(data=df_category_vs_count, x='App Catagory', y='No. of Apps')
plt.xticks(rotation=75)
plt.title('Number of apps in different category',fontsize=15)
plt.xlabel('App Catagory',fontsize=15)
plt.ylabel('No. of Apps',fontsize=15)
# Out:
# Text(0, 0.5, 'No. of Apps')

# %% [markdown]
# **Insights :**
#
# 1.   Family category has the most number of apps followed by Game and Tools category.
# 2.  Bottom three categories are Parenting , Comics and Beauty.
# 3.   We can see the popularity of catagories in terms of no. of apps

# %% [markdown]
# # **Problem 2. Which is the most popular category among the users?**

# %% [markdown]
# To solve this probem we will extract average app downloads in each catagory sort them and then will plot a row chart to see the trend.

# %%
# doing groupby operation and finding avg installs and then sorting
df_category_vs_installs = df.groupby('Category')["Installs"].mean().sort_values(ascending=False).reset_index()
# renaming the columns of relevent data frame
df_category_vs_installs.rename(columns = {'Category':'App Catagory', 'Installs':'Avg_installs'}, inplace = True)

df_category_vs_installs
# Out:
#            App Catagory  Avg_installs
# 0         COMMUNICATION  6.598983e+07
# 1                SOCIAL  4.469239e+07
# 2         VIDEO_PLAYERS  3.555430e+07
# 3          PRODUCTIVITY  3.062185e+07
# 4           PHOTOGRAPHY  3.019021e+07
# 5                  GAME  2.813918e+07
# 6      TRAVEL_AND_LOCAL  2.684341e+07
# 7         ENTERTAINMENT  2.212306e+07
# 8    NEWS_AND_MAGAZINES  2.042886e+07
# 9                 TOOLS  1.358573e+07
# 10             SHOPPING  1.148816e+07
# 11  BOOKS_AND_REFERENCE  8.332476e+06
# 12      PERSONALIZATION  5.346636e+06
# 13  MAPS_AND_NAVIGATION  5.286729e+06
# 14              WEATHER  5.196348e+06
# 15               FAMILY  5.170799e+06
# 16   HEALTH_AND_FITNESS  4.447786e+06
# 17               SPORTS  4.354913e+06
# 18            EDUCATION  4.107323e+06
# 19              FINANCE  2.139858e+06
# 20       FOOD_AND_DRINK  2.079829e+06
# 21             BUSINESS  2.022634e+06
# 22       ART_AND_DESIGN  1.912894e+06
# 23       HOUSE_AND_HOME  1.565156e+06
# 24            LIFESTYLE  1.433843e+06
# 25               DATING  1.053756e+06
# 26               COMICS  9.347692e+05
# 27   LIBRARIES_AND_DEMO  7.411284e+05
# 28    AUTO_AND_VEHICLES  6.250613e+05
# 29            PARENTING  5.253518e+05
# 30               BEAUTY  5.131519e+05
# 31               EVENTS  2.495806e+05
# 32              MEDICAL  1.034416e+05

# %%
# plotting a row chart to see the trend
plt.figure(figsize=(15, 8))
sns.barplot(data = df_category_vs_installs, x ='Avg_installs', y='App Catagory', linewidth=2)
plt.title('Number of installs in each category of apps.',fontsize=18)
plt.xlabel('Average installs', fontsize=15)
plt.ylabel('App Category', fontsize=15)
# Out:
# Text(0, 0.5, 'App Category')

# %% [markdown]
# **Insights :**
#
#
# 1.   We can see that communication related apps has most downloads
# 2.   Medical apps have least no of users.

# %% [markdown]
# We have concluded in earlier problem statement that Medical catagory has 5th highest no. of apps but it has least no of users , we can see these kind of disparity in many of these categories. To refect upon this we will frame next Problem Statement.

# %% [markdown]
# # **Problem 3. Is there any disparity in app installs and no. of apps present in each category?**

# %% [markdown]
# To solve this problem and draw insight we need to merge two of the data frames that we created in above two problems.

# %%
# merging two data frames given above
df_installs_vs_counts = pd.merge(df_category_vs_count, df_category_vs_installs, on='App Catagory')
df_installs_vs_counts
# Out:
#            App Catagory  No. of Apps  Avg_installs
# 0                FAMILY         1942  5.170799e+06
# 1                  GAME         1121  2.813918e+07
# 2                 TOOLS          843  1.358573e+07
# 3              BUSINESS          427  2.022634e+06
# 4               MEDICAL          408  1.034416e+05
# 5          PRODUCTIVITY          407  3.062185e+07
# 6       PERSONALIZATION          388  5.346636e+06
# 7             LIFESTYLE          373  1.433843e+06
# 8         COMMUNICATION          366  6.598983e+07
# 9               FINANCE          360  2.139858e+06
# 10               SPORTS          351  4.354913e+06
# 11          PHOTOGRAPHY          322  3.019021e+07
# 12   HEALTH_AND_FITNESS          306  4.447786e+06
# 13               SOCIAL          280  4.469239e+07
# 14   NEWS_AND_MAGAZINES          264  2.042886e+07
# 15     TRAVEL_AND_LOCAL          237  2.684341e+07
# 16  BOOKS_AND_REFERENCE          230  8.332476e+06
# 17             SHOPPING          224  1.148816e+07
# 18               DATING          196  1.053756e+06
# 19        VIDEO_PLAYERS          175  3.555430e+07
# 20  MAPS_AND_NAVIGATION          137  5.286729e+06
# 21            EDUCATION          130  4.107323e+06
# 22       FOOD_AND_DRINK          124  2.079829e+06
# 23        ENTERTAINMENT          111  2.212306e+07
# 24   LIBRARIES_AND_DEMO           85  7.411284e+05
# 25    AUTO_AND_VEHICLES           85  6.250613e+05
# 26              WEATHER           82  5.196348e+06
# 27       HOUSE_AND_HOME           80  1.565156e+06
# 28       ART_AND_DESIGN           65  1.912894e+06
# 29               EVENTS           64  2.495806e+05
# 30            PARENTING           60  5.253518e+05
# 31               COMICS           60  9.347692e+05
# 32               BEAUTY           53  5.131519e+05

# %%
# plotting the above data set in which there are two Y axis (No of apps and App category) and common x axis (app catagory)
fig = plt.figure(figsize =(20,10))
ax = fig.add_subplot(111)
ax.set_xlabel('App category',fontsize = 18) 
ax.set_ylabel('No. of Apps',fontsize = 18)
ax2 = ax.twinx()
ax2.set_ylabel('Average Installs',fontsize = 18)
width = 0.5
plt.title('Category wise number of Apps and  their Average installs',fontsize=18)
df_category_vs_count.plot(kind='bar', color='blue', ax=ax, width=0.3 , position=0)
df_category_vs_installs.plot(kind='bar', color='green', ax=ax2, width=0.3, position=1)
ax.set_xlabel('Index of each category',fontsize = 18)
# Out:
# Text(0.5, 0, 'Index of each category')

# %% [markdown]
# **Insights:**
#
#
#   We can see from the above graph that there exists some disparity in availability of apps and its users for example lets consider index no 4 from the graph which is the catagory 'MEDICAL' we can see that there are quite a few apps but very less people to serve.

# %% [markdown]
# # **Problem 4 : How each category of apps perform in terms of customer sentiments?**

# %% [markdown]
# To solve this problem we need data form both the given data sets , first we will extract sentiments of users from the 2nd data set and then we will club it with app category which we will get from the first data set.

# %%
# using groupby operation to get the sentiment of users per app
relevent_df1 = df1.groupby(['App','Sentiment'])['Translated_Review'].count().unstack()

# %%
# grabbing app and category column from the first data set
relevent_df2 =  df[['App','Category']]

# %%
# lets do left join on app for above two dataset
relevent_df3 = pd.merge(relevent_df1, relevent_df2, left_on='App',right_on='App', how='left')
# doing aggregate groupby operation 
df_catagory_vs_sentiments = relevent_df3.groupby('Category').agg({'Positive': 'sum', 'Neutral': 'sum' ,'Negative': 'sum'})
df_catagory_vs_sentiments
# Out:
#                      Positive  Neutral  Negative
# Category
# ART_AND_DESIGN          240.0     60.0      54.0
# AUTO_AND_VEHICLES       230.0     36.0      17.0
# BEAUTY                  176.0     81.0      60.0
# BOOKS_AND_REFERENCE     480.0    123.0     108.0
# BUSINESS                458.0    201.0     144.0
# COMICS                   72.0      6.0       2.0
# COMMUNICATION           823.0    211.0     254.0
# DATING                  897.0    268.0     322.0
# EDUCATION               560.0     90.0      87.0
# ENTERTAINMENT           528.0    121.0     218.0
# EVENTS                  123.0     17.0      16.0
# FAMILY                 2251.0    315.0     984.0
# FINANCE                1012.0    219.0     350.0
# FOOD_AND_DRINK          501.0     78.0      83.0
# GAME                   5394.0    414.0    3485.0
# HEALTH_AND_FITNESS     1456.0    217.0     215.0
# HOUSE_AND_HOME          308.0    111.0      85.0
# LIBRARIES_AND_DEMO      237.0     44.0      51.0
# LIFESTYLE               605.0    171.0     165.0
# MAPS_AND_NAVIGATION     126.0     36.0      27.0
# MEDICAL                 914.0    201.0     193.0
# NEWS_AND_MAGAZINES      558.0    128.0     211.0
# PARENTING               181.0     52.0      23.0
# PERSONALIZATION         807.0    188.0     196.0
# PHOTOGRAPHY            1032.0    191.0     305.0
# PRODUCTIVITY           1107.0    239.0     309.0
# SHOPPING                645.0    140.0     207.0
# SOCIAL                  517.0    150.0     308.0
# SPORTS                 1006.0    211.0     393.0
# TOOLS                  1013.0    353.0     296.0
# TRAVEL_AND_LOCAL       1093.0    297.0     375.0
# VIDEO_PLAYERS           185.0     58.0      83.0
# WEATHER                 158.0     35.0      33.0

# %%
# lets plot the above data frame to visualize the trend
plt.plot(df_catagory_vs_sentiments)
plt.title('Customer Sentiments VS Category of Apps ( Blue = "Positive" Green = "Negative" Orange = "Neutral" )' , fontsize = 18)
plt.ylabel('Customer Sentiments',fontsize = 18)
plt.xlabel('App Category',fontsize = 18)
plt.xticks(rotation=75)
plt.rcParams['figure.figsize'] = (20,8)

# %% [markdown]
# **Insights :**
#
# 1.  Most categories have positve reviews.
# 2.  Some categoris like Family and Game have relatively more negative reviews.
#
# 3.   Some categories like Comics have mixed sentiments.

# %% [markdown]
# # **Problem 5 : Compare the number of apps present in the market and number of installations based on the Content Rating.**

# %% [markdown]
# we can approach this problem by extracting two data frames based on Content Ratings :
#
# 1.   Average Number of apps in each category based on Content Rating
# 2.   Number of average installations in each category based on Content Rating.

# %%
# doing groupby operation catagory wise and counting the number of apps per ratings
catagory_vs_content_rating = df.groupby(['Category','Content Rating']).App.count().unstack()
df_catagory_vs_content_rating = catagory_vs_content_rating.replace(np.nan,0,regex = True) #replacing null values with zero
df_catagory_vs_content_rating
# Out:
# Content Rating       Adults only 18+  Everyone  Everyone 10+  Mature 17+  \
# Category
# ART_AND_DESIGN                   0.0      61.0           1.0         0.0
# AUTO_AND_VEHICLES                0.0      83.0           1.0         0.0
# BEAUTY                           0.0      45.0           2.0         3.0
# BOOKS_AND_REFERENCE              0.0     201.0           5.0         3.0
# BUSINESS                         0.0     412.0           1.0         1.0
# COMICS                           2.0      26.0           3.0         7.0
# COMMUNICATION                    0.0     325.0           0.0        10.0
# DATING                           0.0      18.0           0.0       168.0
# EDUCATION                        0.0     121.0           5.0         3.0
# ENTERTAINMENT                    0.0      37.0           2.0         6.0
# EVENTS                           0.0      53.0           3.0         0.0
# FAMILY                           0.0    1501.0         129.0        50.0
# FINANCE                          0.0     355.0           0.0         0.0
# FOOD_AND_DRINK                   0.0     114.0           2.0         0.0
# GAME                             0.0     595.0         128.0        72.0
# HEALTH_AND_FITNESS               0.0     275.0           6.0         6.0
# HOUSE_AND_HOME                   0.0      78.0           0.0         0.0
# LIBRARIES_AND_DEMO               0.0      85.0           0.0         0.0
# LIFESTYLE                        0.0     337.0           5.0         9.0
# MAPS_AND_NAVIGATION              0.0     133.0           1.0         1.0
# MEDICAL                          0.0     390.0           8.0         5.0
# NEWS_AND_MAGAZINES               0.0     168.0          51.0        13.0
# PARENTING                        0.0      58.0           0.0         1.0
# PERSONALIZATION                  0.0     320.0           5.0         9.0
# PHOTOGRAPHY                      0.0     307.0           0.0         4.0
# PRODUCTIVITY                     0.0     396.0           1.0         1.0
# SHOPPING                         0.0     183.0           0.0         3.0
# SOCIAL                           0.0      98.0           2.0        59.0
# SPORTS                           1.0     318.0          12.0         6.0
# TOOLS                            0.0     835.0           0.0         2.0
# TRAVEL_AND_LOCAL                 0.0     230.0           0.0         1.0
# VIDEO_PLAYERS                    0.0     146.0           2.0         3.0
# WEATHER                          0.0      78.0           1.0         1.0
#
# Content Rating        Teen  Unrated
# Category
# ART_AND_DESIGN         3.0      0.0
# AUTO_AND_VEHICLES      1.0      0.0
# BEAUTY                 3.0      0.0
# BOOKS_AND_REFERENCE   21.0      0.0
# BUSINESS              13.0      0.0
# COMICS                22.0      0.0
# COMMUNICATION         31.0      0.0
# DATING                10.0      0.0
# EDUCATION              1.0      0.0
# ENTERTAINMENT         66.0      0.0
# EVENTS                 8.0      0.0
# FAMILY               261.0      1.0
# FINANCE                5.0      0.0
# FOOD_AND_DRINK         8.0      0.0
# GAME                 326.0      0.0
# HEALTH_AND_FITNESS    19.0      0.0
# HOUSE_AND_HOME         2.0      0.0
# LIBRARIES_AND_DEMO     0.0      0.0
# LIFESTYLE             22.0      0.0
# MAPS_AND_NAVIGATION    2.0      0.0
# MEDICAL                5.0      0.0
# NEWS_AND_MAGAZINES    32.0      0.0
# PARENTING              1.0      0.0
# PERSONALIZATION       54.0      0.0
# PHOTOGRAPHY           11.0      0.0
# PRODUCTIVITY           9.0      0.0
# SHOPPING              38.0      0.0
# SOCIAL               121.0      0.0
# SPORTS                14.0      0.0
# TOOLS                  5.0      1.0
# TRAVEL_AND_LOCAL       6.0      0.0
# VIDEO_PLAYERS         24.0      0.0
# WEATHER                2.0      0.0

# %%
# Plotting Average number of apps VS Content Ratings
sns.barplot(data = df_catagory_vs_content_rating)
plt.title('Average number of apps VS Content Ratings', fontsize = 18)
plt.ylabel('No. of Apps',fontsize = 18)
plt.xlabel('Content Ratings',fontsize = 18)
plt.xticks(rotation=75)
# plt.rcParams['figure.figsize'] = (15,8)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# We can see from the above plot that most of apps that are present in the market are rated for everyone.

# %%
# doing groupby operation catagory wise and counting the number of apps per ratings
category_vs_content_rating_istalls = df.groupby(['Category','Content Rating']).Installs.mean().unstack()
df_category_vs_content_rating_istalls = category_vs_content_rating_istalls.replace(np.nan,0,regex = True)
df_category_vs_content_rating_istalls
# Out:
# Content Rating       Adults only 18+      Everyone  Everyone 10+  \
# Category
# ART_AND_DESIGN                   0.0  1.046362e+06  5.000000e+05
# AUTO_AND_VEHICLES                0.0  5.075929e+05  1.000000e+06
# BEAUTY                           0.0  5.937122e+05  5.500000e+04
# BOOKS_AND_REFERENCE              0.0  1.175341e+06  4.222000e+06
# BUSINESS                         0.0  2.096024e+06  1.000000e+02
# COMICS                      500000.0  4.798500e+05  1.700167e+05
# COMMUNICATION                    0.0  6.811554e+07  0.000000e+00
# DATING                           0.0  1.120776e+05  0.000000e+00
# EDUCATION                        0.0  4.123157e+06  6.400000e+06
# ENTERTAINMENT                    0.0  1.313649e+07  5.500000e+06
# EVENTS                           0.0  2.785840e+05  3.370000e+04
# FAMILY                           0.0  4.087569e+06  1.299926e+07
# FINANCE                          0.0  2.166864e+06  0.000000e+00
# FOOD_AND_DRINK                   0.0  2.111299e+06  5.500000e+04
# GAME                             0.0  3.171013e+07  6.429578e+07
# HEALTH_AND_FITNESS               0.0  4.829893e+06  2.583517e+05
# HOUSE_AND_HOME                   0.0  1.598750e+06  0.000000e+00
# LIBRARIES_AND_DEMO               0.0  7.411284e+05  0.000000e+00
# LIFESTYLE                        0.0  1.197711e+06  2.040200e+06
# MAPS_AND_NAVIGATION              0.0  5.407307e+06  1.000000e+02
# MEDICAL                          0.0  1.074750e+05  2.151375e+04
# NEWS_AND_MAGAZINES               0.0  6.311639e+05  2.170504e+07
# PARENTING                        0.0  5.408812e+05  0.000000e+00
# PERSONALIZATION                  0.0  4.436117e+06  2.502000e+06
# PHOTOGRAPHY                      0.0  3.012619e+07  0.000000e+00
# PRODUCTIVITY                     0.0  3.144718e+07  5.000000e+03
# SHOPPING                         0.0  6.143162e+06  0.000000e+00
# SOCIAL                           0.0  6.354846e+06  5.050000e+05
# SPORTS                     1000000.0  4.098905e+06  5.463417e+06
# TOOLS                            0.0  1.364395e+07  0.000000e+00
# TRAVEL_AND_LOCAL                 0.0  2.752299e+07  0.000000e+00
# VIDEO_PLAYERS                    0.0  1.852840e+07  5.050000e+06
# WEATHER                          0.0  5.314109e+06  1.000000e+07
#
# Content Rating         Mature 17+          Teen  Unrated
# Category
# ART_AND_DESIGN       0.000000e+00  2.000333e+07      0.0
# AUTO_AND_VEHICLES    0.000000e+00  1.000000e+07      0.0
# BEAUTY               4.000000e+04  8.333333e+04      0.0
# BOOKS_AND_REFERENCE  1.833667e+06  7.874357e+07      0.0
# BUSINESS             5.000000e+00  7.917692e+03      0.0
# COMICS               3.300000e+05  1.808636e+06      0.0
# COMMUNICATION        3.801100e+07  5.272957e+07      0.0
# DATING               1.205404e+06  2.010910e+05      0.0
# EDUCATION            6.833333e+05  1.000000e+06      0.0
# ENTERTAINMENT        3.850000e+06  2.932591e+07      0.0
# EVENTS               0.000000e+00  1.383888e+05      0.0
# FAMILY               1.278601e+06  8.296618e+06    500.0
# FINANCE              0.000000e+00  2.224000e+05      0.0
# FOOD_AND_DRINK       0.000000e+00  2.137576e+06      0.0
# GAME                 1.200864e+07  1.098777e+07      0.0
# HEALTH_AND_FITNESS   6.835000e+05  1.428989e+06      0.0
# HOUSE_AND_HOME       0.000000e+00  2.550000e+05      0.0
# LIBRARIES_AND_DEMO   0.000000e+00  0.000000e+00      0.0
# LIFESTYLE            1.251289e+07  3.808100e+05      0.0
# MAPS_AND_NAVIGATION  1.000000e+04  2.550000e+06      0.0
# MEDICAL              1.114000e+04  1.222200e+04      0.0
# NEWS_AND_MAGAZINES   8.027039e+07  9.802219e+07      0.0
# PARENTING            1.000000e+05  5.000000e+04      0.0
# PERSONALIZATION      1.912233e+05  1.186493e+07      0.0
# PHOTOGRAPHY          5.275000e+07  2.377336e+07      0.0
# PRODUCTIVITY         1.000000e+03  1.111347e+06      0.0
# SHOPPING             5.033333e+06  3.773816e+07      0.0
# SOCIAL               2.228171e+07  8.740051e+07      0.0
# SPORTS               3.666667e+06  9.754400e+06      0.0
# TOOLS                2.550000e+03  1.200402e+07  50000.0
# TRAVEL_AND_LOCAL     1.000000e+07  3.600008e+06      0.0
# VIDEO_PLAYERS        3.533333e+06  1.456732e+08      0.0
# WEATHER              1.000000e+06  3.000000e+05      0.0

# %%
# Plotting the graph for average installations based on Content rating
sns.barplot(data = category_vs_content_rating_istalls)   
plt.title('Average  installations based on Content rating', fontsize = 18)
plt.ylabel('No. of app installs',fontsize = 18)
plt.xlabel('Content Ratings',fontsize = 18)
plt.xticks(rotation=75)
# plt.rcParams['figure.figsize'] = (20,8)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# We can see frm the above bar graph that the maximum number of installed apps are related to content rating 'Teen'.

# %% [markdown]
# **Insights :**
#
#    what we can infer from above two graphs that "Everyone" rated apps are available in abundance but "Teen" and "Mature 17+" rated have large no. of users.

# %% [markdown]
# # **Problem 6. What are the top 10 apps that is mostly installed ?**

# %% [markdown]
# we can approach this question by gabbing columns 'App','Category' and 'Installs' from the original dataset and then we will the output in descending order based on Installs.

# %%
# grabbing the 'App','Category'and 'Installs' columns
relevent_df =df[['App','Category','Installs', 'Rating']]
df_top_apps =relevent_df.sort_values(by=['Installs'],ascending = False).head(10)
df_top_apps
# Out:
#                                App       Category      Installs  Rating
# 341                       Hangouts  COMMUNICATION  1.000000e+09     4.0
# 3928                       YouTube  VIDEO_PLAYERS  1.000000e+09     4.3
# 451                          Gmail  COMMUNICATION  1.000000e+09     4.3
# 3996  Google Chrome: Fast & Secure  COMMUNICATION  1.000000e+09     4.3
# 1700                Subway Surfers           GAME  1.000000e+09     4.5
# 3454                  Google Drive   PRODUCTIVITY  1.000000e+09     4.4
# 2808                 Google Photos    PHOTOGRAPHY  1.000000e+09     4.5
# 865              Google Play Games  ENTERTAINMENT  1.000000e+09     4.3
# 2853                 Google Photos    PHOTOGRAPHY  1.000000e+09     4.5
# 411   Google Chrome: Fast & Secure  COMMUNICATION  1.000000e+09     4.3

# %% [markdown]
# **Insights:**
#
#   we can collect from the table that these ten apps of different mentioned category are best performing apps and category.

# %% [markdown]
# # **Problem 7. What is the ratio of free and paid apps in each  category?**

# %%
# Doing Groupby operation by category and type 
category_vs_type_df =df.groupby(['Category','Type'])['App'].count().unstack()

# %%
category_vs_type_df = category_vs_type_df.replace(np.nan,0,regex=True) #replacing nan values from new dataframe
category_vs_type_df
# Out:
# Type                   Free   Paid
# Category
# ART_AND_DESIGN         62.0    3.0
# AUTO_AND_VEHICLES      82.0    3.0
# BEAUTY                 53.0    0.0
# BOOKS_AND_REFERENCE   202.0   28.0
# BUSINESS              415.0   12.0
# COMICS                 60.0    0.0
# COMMUNICATION         339.0   27.0
# DATING                189.0    7.0
# EDUCATION             126.0    4.0
# ENTERTAINMENT         109.0    2.0
# EVENTS                 63.0    1.0
# FAMILY               1755.0  187.0
# FINANCE               343.0   17.0
# FOOD_AND_DRINK        122.0    2.0
# GAME                 1038.0   83.0
# HEALTH_AND_FITNESS    291.0   15.0
# HOUSE_AND_HOME         80.0    0.0
# LIBRARIES_AND_DEMO     84.0    1.0
# LIFESTYLE             354.0   19.0
# MAPS_AND_NAVIGATION   132.0    5.0
# MEDICAL               324.0   84.0
# NEWS_AND_MAGAZINES    262.0    2.0
# PARENTING              58.0    2.0
# PERSONALIZATION       306.0   82.0
# PHOTOGRAPHY           302.0   20.0
# PRODUCTIVITY          379.0   28.0
# SHOPPING              222.0    2.0
# SOCIAL                277.0    3.0
# SPORTS                327.0   24.0
# TOOLS                 765.0   78.0
# TRAVEL_AND_LOCAL      225.0   12.0
# VIDEO_PLAYERS         171.0    4.0
# WEATHER                74.0    8.0

# %%
# plotting stacked bar graph to visualize the ratio 
category_vs_type_df.plot(kind= 'bar', stacked = True)
plt.title('No of apps in each category based on type(Free or Paid)', fontsize = 18)
plt.ylabel('Number of Apps',fontsize = 18)
plt.xlabel('App Category',fontsize = 18)
plt.xticks(rotation=75)
plt.rcParams['figure.figsize'] = (20,8)

# %% [markdown]
# # **Probem 8. What is the category wise distribution of average ratings**

# %%
# plotting a box plot category wise to know the avg rating across the category
sns.catplot(x='Category',y='Rating',data=df,kind='box',height=13,showmeans = True)
sns.color_palette("viridis", as_cmap=True)
plt.title("Rating of each category", size=18)
plt.ylabel('Ratings',fontsize = 18)
plt.xlabel('App Category',fontsize = 18)
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# **Insights:**
#
#
#    Almost all category has average rating more than 4.0

# %% [markdown]
# # **Problem 9. What percentage of apps is supported in higher android versions.**

# %%
#counting the values in android version colum and sorting them
count_Android_Ver=pd.value_counts(df["Android Ver"], sort=True) 
count_Android_Ver.reset_index()
# Out:
#                  index  Android Ver
# 0           4.1 and up         2381
# 1         4.0.3 and up         1451
# 2           4.0 and up         1337
# 3   Varies with device         1220
# 4           4.4 and up          894
# 5           2.3 and up          643
# 6           5.0 and up          546
# 7           4.2 and up          387
# 8         2.3.3 and up          279
# 9           2.2 and up          239
# 10          3.0 and up          237
# 11          4.3 and up          235
# 12          2.1 and up          133
# 13          1.6 and up          116
# 14          6.0 and up           58
# 15          7.0 and up           42
# 16          3.2 and up           36
# 17          2.0 and up           32
# 18          5.1 and up           22
# 19          1.5 and up           20
# 20         4.4W and up           11
# 21          3.1 and up           10
# 22        2.0.1 and up            7
# 23          8.0 and up            6
# 24          7.1 and up            3
# 25       4.0.3 - 7.1.1            2
# 26           5.0 - 8.0            2
# 27          1.0 and up            2
# 28         7.0 - 7.1.1            1
# 29         4.1 - 7.1.1            1
# 30           5.0 - 6.0            1
# 31         2.2 - 7.1.1            1
# 32         5.0 - 7.1.1            1

# %%
#plotting bar graph to know the percentage 
plt.figure(figsize=(15,10))
count_Android_Ver.plot(kind = 'pie',  autopct='%1.02f%%', shadow=True)
plt.title('Different android Version supported in apps',size=20)
plt.show()

# %% [markdown]
# **Insights:**
#
#    we can infer from the above table and pie chart that approx 60% of the are supported in Android 4.0 and above , other 40% apps needs updation.

# %% [markdown]
# # **Problem 10. What are the top 10 Genres in terms of app availability?**

# %%
df_genre_vs_count = df.groupby('Genres').App.count().sort_values(ascending = False).reset_index().head(10)
df_genre_vs_count
# Out:
#             Genres  App
# 0            Tools  842
# 1    Entertainment  588
# 2        Education  527
# 3         Business  427
# 4          Medical  408
# 5     Productivity  407
# 6  Personalization  388
# 7        Lifestyle  372
# 8    Communication  366
# 9           Sports  364

# %%
df_genre_vs_count.plot(kind='bar')
plt.title('Top Genres vs No. of apps',fontsize=18)
plt.xlabel('Top 10 Genres', fontsize=15)
plt.ylabel('No. of Apps', fontsize=15)
plt.show()

# %% [markdown]
# **Category Wise top 10 best apps (Free and Paid)**

# %% [markdown]
# Lets check the best apps in medical category

# %%
a=df[(df.Category == 'MEDICAL')&(df.Type == 'Free')][['App']].head(10)
b=df[(df.Category == 'MEDICAL')&(df.Type == 'Paid')][['App']].head(10)

# %%
a
# Out:
#                                                    App
# 2303                    GoodRx Drug Prices and Coupons
# 2304                                           MyChart
# 2305                                   FollowMyHealth®
# 2306                                          CareZone
# 2307  Ovia Pregnancy Tracker & Baby Countdown Calendar
# 2308                                    Teladoc Member
# 2309                       myAir™ for Air10™ by ResMed
# 2310                                    Blood Pressure
# 2311                            Pregnancy Week By Week
# 2312                                  Doctor On Demand

# %%
b
# Out:
#                                                    App
# 2243                        Monash Uni Low FODMAP Diet
# 2244                                iBP Blood Pressure
# 2245                                         Pedi STAT
# 2246                                      ASCCP Mobile
# 2247                            Journal Club: Medicine
# 2248                       Paramedic Protocol Provider
# 2249                                         MommyMeds
# 2250           Medical ID - In Case of Emergency (ICE)
# 2251  Human Anatomy Atlas 2018: Complete 3D Human Body
# 2252                               Essential Anatomy 3

# %% [markdown]
# # **Recommendations :**

# %% [markdown]
# 1.   Some of the Categories like Communication, Social Media , Video Player and Gaming are highly in demand among users but there are very few apps to cater So there is huge gap in the market where business can be built.
#
# 2.   Gaming category is popular among users and service providers as well but we can observe some negative sentiments among the users for this category . So Gaming firms can improve their services for hassle free experience among users.
#
# 3.   Playstore has maximum number of apps rated for everone but the users are downloading teen and mature 17+ more. So there is scope of building business around it.
# 4.  There is a very few app that are paid in the app store so there is scope of building business around monthly or yearly subscription model. Ed tech , Gaming, Entertainment has enormous potential to act in this regard.
